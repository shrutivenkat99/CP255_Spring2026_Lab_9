# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutivenkat99/CP255_Spring2026_Lab_9/blob/main/notebooks/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Clone repository
# !git clone https://github.com/danielandreawilson-tech/Bay_area_employment_trends_final-.git
# Out:
# fatal: destination path 'Bay_area_employment_trends_final-' already exists and is not an empty directory.

# %%
# Move into project folder
# %cd Bay_area_employment_trends_final-
# Out:
# /content/Bay_area_employment_trends_final-

# %%
from pathlib import Path
import os
import sys

# %cd /content/Bay_area_employment_trends_final-
# project root = parent folder of the notebook folder
PROJECT_ROOT = Path.cwd()

# move working directory to project root
os.chdir(PROJECT_ROOT)

# define project folders as per the assignment structure
DATA_DIR = PROJECT_ROOT / "data"
RAW_DIR = DATA_DIR / "raw"
PROCESSED_DIR = DATA_DIR / "processed"
VIS_DIR = PROJECT_ROOT / "visualizations"
SRC_DIR = PROJECT_ROOT / "src"

# allow imports from src/
sys.path.append(str(SRC_DIR))

# check path
print("Project root:", PROJECT_ROOT)
print("Current working directory:", os.getcwd())
# Out:
# /content/Bay_area_employment_trends_final-
# Project root: /content/Bay_area_employment_trends_final-
# Current working directory: /content/Bay_area_employment_trends_final-

# %%
print(os.getcwd()) # check if the path worked
# Out:
# /content/Bay_area_employment_trends_final-

# %%
# !ls data/raw/csv
# Out:
# csv-20260511T070151Z-3-001.zip

# %%
# import raw data

import zipfile

import pandas as pd

zip_path = RAW_DIR / "csv" / "csv-20260511T070151Z-3-001.zip"
with zipfile.ZipFile(zip_path) as z:
    raw_df = pd.read_csv(
        z.open("csv/RawData.csv")
    )

# %%
raw_df.columns #show columns to check for formatting
# Out:
# Index(['periodicity', 'periodicity_label.value', 'seasonadj',
#        'seasonadj_label.value', 'geo_level', 'geo_level_label.value',
#        'geography', 'geography_label.value', 'ind_level', 'industry',
#        'industry_label.value', 'ownercode', 'ownercode_label.value', 'sex',
#        'sex_label.value', 'agegrp', 'agegrp_label.value', 'race',
#        'race_label.value', 'ethnicity', 'ethnicity_label.value', 'education',
#        'education_label.value', 'firmage', 'firmage_label.value', 'firmsize',
#        'firmsize_label.value', 'year', 'quarter', 'agg_level', 'EmpS',
#        'sEmpS'],
#       dtype='object')

# %%
pre_cleaned_df = raw_df.copy()

# standardize column names to snake_case
pre_cleaned_df.columns = raw_df.columns.str.lower().str.replace('.', '_', regex=False).str.replace(' ', '_', regex=False)

pre_cleaned_df.columns
# Out:
# Index(['periodicity', 'periodicity_label_value', 'seasonadj',
#        'seasonadj_label_value', 'geo_level', 'geo_level_label_value',
#        'geography', 'geography_label_value', 'ind_level', 'industry',
#        'industry_label_value', 'ownercode', 'ownercode_label_value', 'sex',
#        'sex_label_value', 'agegrp', 'agegrp_label_value', 'race',
#        'race_label_value', 'ethnicity', 'ethnicity_label_value', 'education',
#        'education_label_value', 'firmage', 'firmage_label_value', 'firmsize',
#        'firmsize_label_value', 'year', 'quarter', 'agg_level', 'emps',
#        'semps'],
#       dtype='object')

# %%
# drop columns that are not useful for our analysis
pre_cleaned_df = pre_cleaned_df.drop(['periodicity', 'periodicity_label_value', 'agegrp', 'agegrp_label_value', 'seasonadj',	'seasonadj_label_value', 'sex', 'sex_label_value', 'education',
       'education_label_value', 'firmage', 'firmage_label_value','quarter'], axis=1)

pre_cleaned_df.head(5)
# Out:
#   geo_level geo_level_label_value  geography geography_label_value ind_level  \
# 0         S                States          6            California         A
# 1         S                States          6            California         A
# 2         S                States          6            California         A
# 3         S                States          6            California         A
# 4         S                States          6            California         A
#
#   industry industry_label_value ownercode ownercode_label_value race  \
# 0       00    All NAICS Sectors       A05           All Private   A0
# 1       00    All NAICS Sectors       A05           All Private   A0
# 2       00    All NAICS Sectors       A05           All Private   A0
# 3       00    All NAICS Sectors       A05           All Private   A1
# 4       00    All NAICS Sectors       A05           All Private   A1
#
#   race_label_value ethnicity   ethnicity_label_value  firmsize  \
# 0        All Races        A0         All Ethnicities         0
# 1        All Races        A1  Not Hispanic or Latino         0
# 2        All Races        A2      Hispanic or Latino         0
# 3      White Alone        A0         All Ethnicities         0
# 4      White Alone        A1  Not Hispanic or Latino         0
#
#   firmsize_label_value  year  agg_level        emps  semps
# 0       All Firm Sizes  2018       1057  12963342.0      1
# 1       All Firm Sizes  2018       1065   8468553.0      1
# 2       All Firm Sizes  2018       1065   4494789.0      1
# 3       All Firm Sizes  2018       1061   9153163.0      1
# 4       All Firm Sizes  2018       1069   5180850.0      1

# %%
# check for data types so to avoid calculation issues
print(pre_cleaned_df.dtypes)
# Out:
# geo_level                 object
# geo_level_label_value     object
# geography                  int64
# geography_label_value     object
# ind_level                 object
# industry                  object
# industry_label_value      object
# ownercode                 object
# ownercode_label_value     object
# race                      object
# race_label_value          object
# ethnicity                 object
# ethnicity_label_value     object
# firmsize                   int64
# firmsize_label_value      object
# year                       int64
# agg_level                  int64
# emps                     float64
# semps                      int64
# dtype: object

# %%
# fixing data types just to keep consistency throughout datasets even if not essential in this case (geography, year, earnings, n_employed)
pre_cleaned_df['geography'] = pre_cleaned_df['geography'].astype(str)
pre_cleaned_df['year_pd'] = pd.to_datetime(pre_cleaned_df['year'], format="%Y", errors="coerce") # errors="coerce" brings NaN if missing
pre_cleaned_df['n_employed'] = pd.to_numeric(pre_cleaned_df['emps'], errors='coerce').astype("Int64")

# %%
print(pre_cleaned_df.dtypes) #sanity check that our change worked
# Out:
# geo_level                        object
# geo_level_label_value            object
# geography                        object
# geography_label_value            object
# ind_level                        object
# industry                         object
# industry_label_value             object
# ownercode                        object
# ownercode_label_value            object
# race                             object
# race_label_value                 object
# ethnicity                        object
# ethnicity_label_value            object
# firmsize                          int64
# firmsize_label_value             object
# year                              int64
# agg_level                         int64
# emps                            float64
# semps                             int64
# year_pd                  datetime64[ns]
# n_employed                        Int64
# dtype: object

# %%
# we drop extra columns after fixing data types since we will not use these
pre_cleaned_df = pre_cleaned_df.drop(['emps', 'year','semps'], axis=1)

# %%
print(pre_cleaned_df.dtypes)
# Out:
# geo_level                        object
# geo_level_label_value            object
# geography                        object
# geography_label_value            object
# ind_level                        object
# industry                         object
# industry_label_value             object
# ownercode                        object
# ownercode_label_value            object
# race                             object
# race_label_value                 object
# ethnicity                        object
# ethnicity_label_value            object
# firmsize                          int64
# firmsize_label_value             object
# agg_level                         int64
# year_pd                  datetime64[ns]
# n_employed                        Int64
# dtype: object

# %%
# check for duplicates and if all rows are unique so to avoid double counting. checking for sum of duplicate rows - if its zero then there are no duplicates
print(pre_cleaned_df.duplicated().sum())
# Out:
# 0

# %%
# check for any missing values so to avoid any bias in the results
pre_cleaned_df.isnull().sum().sort_values(ascending=False)
# Out:
# n_employed               13338
# geo_level                    0
# geo_level_label_value        0
# geography                    0
# ind_level                    0
# geography_label_value        0
# industry_label_value         0
# ownercode                    0
# ownercode_label_value        0
# industry                     0
# race                         0
# race_label_value             0
# ethnicity_label_value        0
# ethnicity                    0
# firmsize                     0
# firmsize_label_value         0
# agg_level                    0
# year_pd                      0
# dtype: int64

# %%
# there are some missing values, we want to check how big of an issue this is by using average/mean missing values
pre_cleaned_df[['n_employed']].isnull().mean()
# Out:
# n_employed    0.078181
# dtype: float64

# %%
# we decide not to drop these at the moment but they are a small percentage of all

# %%
# let's check what counties are included. We have pre filtered these while downloading the data so they should be all we want (9 Bay Area counties + California )
pre_cleaned_df["geography_label_value"].unique()
# Out:
# array(['California', 'Alameda, CA', 'Contra Costa, CA', 'Marin, CA',
#        'Napa, CA', 'San Francisco, CA', 'San Mateo, CA',
#        'Santa Clara, CA', 'Solano, CA', 'Sonoma, CA'], dtype=object)

# %%
# we want to keep only bay area counties so we make a list of these and then we ask to keep only the rows that have these counties (remove California)
bay_area_counties = [
    "Alameda, CA",
    "Contra Costa, CA",
    "Marin, CA",
    "Napa, CA",
    "San Francisco, CA",
    "San Mateo, CA",
    "Santa Clara, CA",
    "Solano, CA",
    "Sonoma, CA"
]

pre_cleaned_df = pre_cleaned_df[
    pre_cleaned_df["geography_label_value"].isin(bay_area_counties)
].copy()

# %%
# check whether this worked
pre_cleaned_df["geography_label_value"].unique()
# Out:
# array(['Alameda, CA', 'Contra Costa, CA', 'Marin, CA', 'Napa, CA',
#        'San Francisco, CA', 'San Mateo, CA', 'Santa Clara, CA',
#        'Solano, CA', 'Sonoma, CA'], dtype=object)

# %%
# we have decided to remove California aggregate observations since thats not at the county level

# %%
pre_cleaned_df.head()
# Out:
#       geo_level geo_level_label_value geography geography_label_value  \
# 17829         C              Counties      6001           Alameda, CA
# 17830         C              Counties      6001           Alameda, CA
# 17831         C              Counties      6001           Alameda, CA
# 17832         C              Counties      6001           Alameda, CA
# 17833         C              Counties      6001           Alameda, CA
#
#       ind_level industry industry_label_value ownercode ownercode_label_value  \
# 17829         A       00    All NAICS Sectors       A05           All Private
# 17830         A       00    All NAICS Sectors       A05           All Private
# 17831         A       00    All NAICS Sectors       A05           All Private
# 17832         A       00    All NAICS Sectors       A05           All Private
# 17833         A       00    All NAICS Sectors       A05           All Private
#
#       race race_label_value ethnicity   ethnicity_label_value  firmsize  \
# 17829   A0        All Races        A0         All Ethnicities         0
# 17830   A0        All Races        A1  Not Hispanic or Latino         0
# 17831   A0        All Races        A2      Hispanic or Latino         0
# 17832   A1      White Alone        A0         All Ethnicities         0
# 17833   A1      White Alone        A1  Not Hispanic or Latino         0
#
#       firmsize_label_value  agg_level    year_pd  n_employed
# 17829       All Firm Sizes       4129 2018-01-01      624186
# 17830       All Firm Sizes       4137 2018-01-01      472770
# 17831       All Firm Sizes       4137 2018-01-01      151416
# 17832       All Firm Sizes       4133 2018-01-01      360841
# 17833       All Firm Sizes       4141 2018-01-01      233414

# %%
### SUMMARY STATISTICS - not particularly needed for analysis here but used to describe the data in the report
pre_cleaned_df[["n_employed"]].describe()
# Out:
#          n_employed
# count      139496.0
# mean    2523.293593
# std    17809.247923
# min             0.0
# 25%            14.0
# 50%            90.0
# 75%           664.0
# max        963429.0

# %%
# min n_employed is 0 we know that we have missing values here, we will deal with those later in the code

# %%
# we now want to save this into our processed folder
pre_cleaned_df.to_csv(
    PROCESSED_DIR / "bay_area_cleaned_df.csv",
    index=False
)

# %%
# let's open the newly created cleaned and filtered dataframe and we will call this county_df from now on
county_df = pd.read_csv(
    PROCESSED_DIR / "bay_area_cleaned_df.csv"
)

# %%
# let's check if the 0 all firm sizes is there, we will want to filter only for all in this phase.
county_df["firmsize"].unique()
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
# let's check if the 00 all industries is there, we will want to filter only for all since Vital Signs has already done this type of analysis.
county_df["industry"].unique()
# Out:
# array(['00', '11', '21', '22', '23', '31-33', '42', '44-45', '48-49',
#        '51', '52', '53', '54', '55', '56', '61', '62', '71', '72', '81',
#        '92'], dtype=object)

# %%
# let's check that all races are included A0, we want to filter for all races only in the initial part of the analysis
county_df["race"].unique()
# Out:
# array(['A0', 'A1', 'A2', 'A3', 'A4', 'A5', 'A7'], dtype=object)

# %%
# let's check that all ethnicities (A0) are included
county_df["ethnicity"].unique()
# Out:
# array(['A0', 'A1', 'A2'], dtype=object)

# %%
##### ANALYSIS SECTION 1 ######

# COUNTY TOTALS #

# RECOVERY INDEX ALL FIRM TYPES FOR GENERAL POPULATION

#let's filter for total employment - all industries - all ethnicities - all ownercodes  - all races to calculate Total Recovery index by county and by firmsize
df_totals = county_df[
    (county_df["industry"] == "00") &
    (county_df["race"] == "A0") &
    (county_df["ethnicity"] == "A0") &
    (county_df["ownercode"] == "A05")

].copy()

# %%
# drop n_employed missing values before calculating recovery index to avoid inf
df_totals = df_totals.dropna(subset=["n_employed"])

# %%
# year_pd to datetime (we don't need this but it might be useful in the future)
df_totals["year_pd"] = pd.to_datetime(df_totals["year_pd"])

# %%
df_totals.head()
# Out:
#    geo_level geo_level_label_value  geography geography_label_value ind_level  \
# 0          C              Counties       6001           Alameda, CA         A
# 21         C              Counties       6001           Alameda, CA         A
# 42         C              Counties       6001           Alameda, CA         A
# 63         C              Counties       6001           Alameda, CA         A
# 84         C              Counties       6001           Alameda, CA         A
#
#    industry industry_label_value ownercode ownercode_label_value race  \
# 0        00    All NAICS Sectors       A05           All Private   A0
# 21       00    All NAICS Sectors       A05           All Private   A0
# 42       00    All NAICS Sectors       A05           All Private   A0
# 63       00    All NAICS Sectors       A05           All Private   A0
# 84       00    All NAICS Sectors       A05           All Private   A0
#
#    race_label_value ethnicity ethnicity_label_value  firmsize  \
# 0         All Races        A0       All Ethnicities         0
# 21        All Races        A0       All Ethnicities         1
# 42        All Races        A0       All Ethnicities         2
# 63        All Races        A0       All Ethnicities         3
# 84        All Races        A0       All Ethnicities         4
#
#    firmsize_label_value  agg_level    year_pd  n_employed
# 0        All Firm Sizes       4129 2018-01-01    624186.0
# 21       0-19 Employees       4257 2018-01-01    121183.0
# 42      20-49 Employees       4257 2018-01-01     61141.0
# 63     50-249 Employees       4257 2018-01-01     99856.0
# 84    250-499 Employees       4257 2018-01-01     33673.0

# %%
# let's group by n_employed, year and county so to calculate baseline
df_totals = df_totals.groupby(
    ["geography_label_value", "year_pd","firmsize","firmsize_label_value"]
)["n_employed"].sum().reset_index()

# %%
df_totals.head()
# Out:
#   geography_label_value    year_pd  firmsize firmsize_label_value  n_employed
# 0           Alameda, CA 2018-01-01         0       All Firm Sizes    624186.0
# 1           Alameda, CA 2018-01-01         1       0-19 Employees    121183.0
# 2           Alameda, CA 2018-01-01         2      20-49 Employees     61141.0
# 3           Alameda, CA 2018-01-01         3     50-249 Employees     99856.0
# 4           Alameda, CA 2018-01-01         4    250-499 Employees     33673.0

# %%
######## HELPER CALL ######
from data_cleaning_tools import (
    add_baseline,  # function 1
    add_recovery_index,  # function 2
    plot_trends,  # function 3
    map_race_population,  # function 4
    plot_jobs_per_capita_by_race,  # function 5
    map_ethnicity_population,  # function 6
    plot_recovery_trends  # function 7
)

# %%
# let's apply our baseline employment function (2019) by county which will be necessary to build our recovery index. See helper file for function
df_totals = add_baseline(
    df_totals,
    value_col="n_employed",
    baseline_year=2019,
    group_cols=["geography_label_value", "firmsize"]
)

# %%
# check if we have any missing values as a sanity check
df_totals.isnull().sum().sort_values(ascending=False)
# Out:
# geography_label_value    0
# year_pd                  0
# firmsize                 0
# firmsize_label_value     0
# n_employed               0
# baseline_emp             0
# dtype: int64

# %%
# calculate recovery index on df_totals
df_totals = add_recovery_index(
    df_totals,
    current_col="n_employed",
    baseline_col="baseline_emp",
    recovery_col="recovery_index_all"
)

# %%
df_totals.head(10)
# Out:
#   geography_label_value    year_pd  firmsize firmsize_label_value  n_employed  \
# 0           Alameda, CA 2018-01-01         0       All Firm Sizes    624186.0
# 1           Alameda, CA 2018-01-01         1       0-19 Employees    121183.0
# 2           Alameda, CA 2018-01-01         2      20-49 Employees     61141.0
# 3           Alameda, CA 2018-01-01         3     50-249 Employees     99856.0
# 4           Alameda, CA 2018-01-01         4    250-499 Employees     33673.0
# 5           Alameda, CA 2018-01-01         5       500+ Employees    308332.0
# 6           Alameda, CA 2019-01-01         0       All Firm Sizes    633617.0
# 7           Alameda, CA 2019-01-01         1       0-19 Employees    124883.0
# 8           Alameda, CA 2019-01-01         2      20-49 Employees     63697.0
# 9           Alameda, CA 2019-01-01         3     50-249 Employees     98282.0
#
#    baseline_emp  recovery_index_all
# 0      633617.0           98.511561
# 1      124883.0           97.037227
# 2       63697.0           95.987252
# 3       98282.0          101.601514
# 4       35988.0           93.567300
# 5      310767.0           99.216455
# 6      633617.0          100.000000
# 7      124883.0          100.000000
# 8       63697.0          100.000000
# 9       98282.0          100.000000

# %%
# clean df_totals as county only names (e.g. Alameda, CA to Alameda) this will be our formatting for now on across all datasets
df_totals["county"] = df_totals["geography_label_value"].str.replace(", CA", "", regex=False)

# %%
df_totals.head()
# Out:
#   geography_label_value    year_pd  firmsize firmsize_label_value  n_employed  \
# 0           Alameda, CA 2018-01-01         0       All Firm Sizes    624186.0
# 1           Alameda, CA 2018-01-01         1       0-19 Employees    121183.0
# 2           Alameda, CA 2018-01-01         2      20-49 Employees     61141.0
# 3           Alameda, CA 2018-01-01         3     50-249 Employees     99856.0
# 4           Alameda, CA 2018-01-01         4    250-499 Employees     33673.0
#
#    baseline_emp  recovery_index_all   county
# 0      633617.0           98.511561  Alameda
# 1      124883.0           97.037227  Alameda
# 2       63697.0           95.987252  Alameda
# 3       98282.0          101.601514  Alameda
# 4       35988.0           93.567300  Alameda

# %%
# we drop extra column after fixing column names for county since it is not necessary
df_totals = df_totals.drop(['geography_label_value'], axis=1)

# %%
df_totals.head()
# Out:
#      year_pd  firmsize firmsize_label_value  n_employed  baseline_emp  \
# 0 2018-01-01         0       All Firm Sizes    624186.0      633617.0
# 1 2018-01-01         1       0-19 Employees    121183.0      124883.0
# 2 2018-01-01         2      20-49 Employees     61141.0       63697.0
# 3 2018-01-01         3     50-249 Employees     99856.0       98282.0
# 4 2018-01-01         4    250-499 Employees     33673.0       35988.0
#
#    recovery_index_all   county
# 0           98.511561  Alameda
# 1           97.037227  Alameda
# 2           95.987252  Alameda
# 3          101.601514  Alameda
# 4           93.567300  Alameda

# %%
# using plot-recovery-trends helper function definition to make an interactive chart with all counties

fig = plot_recovery_trends(
    df=df_totals[df_totals["firmsize"] == 0],
    x_col="year_pd",
    y_col="recovery_index_all",
    group_col="county",
    title="Recovery Index by County (Base Year = 2019)",
    legendtitle="Counties:",
    ylabel="Recovery Index (2019 = 100)",
    save_path="visualizations/recovery_index_county.html"
)

# Highlight selected counties and not all of them at the start
start_counties = ["Alameda", "San Francisco"] #pre-select a couple of counties for easier readability
for trace in fig.data:
    if trace.name not in start_counties:
        trace.visible = "legendonly" #allow for still toggling through specific counties
fig.write_html(VIS_DIR / "recovery_index_county.html") # saves it to visualizations using relative path (Github)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c86d0db1-d28c-4c23-9dd7-1967da0aff2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c86d0db1-d28c-4c23-9dd7-1967da0aff2f")) {                    Plotly.newPlot(                        "c86d0db1-d28c-4c23-9dd7-1967da0aff2f",                        [{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alameda","line":{"color":"rgb(102, 197, 204)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"Alameda","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[98.51156140065686,100.0,93.43609783197104,94.30034232036071,99.2189287850547,102.44390538763955,103.46139702691057],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Contra Costa","line":{"color":"rgb(246, 207, 113)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"Contra Costa","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[98.88509082236972,100.0,94.03659392927646,95.08857002795553,99.4339335161705,101.62400466367238,101.61969871616519],"yaxis":"y","type":"scatter","visible":"legendonly"},{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Marin","line":{"color":"rgb(248, 156, 116)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"Marin","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[100.18584319042499,100.0,92.05666464070316,93.30146336902146,97.09313198372995,99.02052456870354,100.87895647295339],"yaxis":"y","type":"scatter","visible":"legendonly"},{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Napa","line":{"color":"rgb(220, 176, 242)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"Napa","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[96.21415112278943,100.0,91.86820405552578,88.34511729216726,95.83902363130326,99.90665030165782,102.58440368558439],"yaxis":"y","type":"scatter","visible":"legendonly"},{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"San Francisco","line":{"color":"rgb(135, 197, 95)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"San Francisco","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00: ...

# %%
firm_size_trends = (
    df_totals[df_totals["firmsize"] != 0]
    .groupby(["year_pd", "firmsize","firmsize_label_value"], as_index=False)
    .agg({
        "n_employed": "sum", # we need to add the number of employed for each county
        "baseline_emp": "sum" # we need to also add the baseline employment for each county
    })

)

# %%
#applies the recovery index function calculated earlier
firm_size_trends = add_recovery_index(
    firm_size_trends,
    current_col="n_employed",
    baseline_col="baseline_emp",
    recovery_col="recovery_index_all"
)

# %%
fig = plot_recovery_trends(
    df=firm_size_trends,
    x_col="year_pd",
    y_col="recovery_index_all",
    group_col="firmsize_label_value",
    title="Recovery Index by Firm Size (Base Year = 2019)",
    legendtitle="Firm Size:",
    ylabel="Recovery Index (2019 = 100)",
    save_path="visualizations/recovery_index_firm_size.html",
)

fig.write_html(
    VIS_DIR / "recovery_index_firm_size.html"
) # saves visualization for GitHub/ArcGIS

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="51452635-cf87-4b04-b05a-9a6f7cd38822" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51452635-cf87-4b04-b05a-9a6f7cd38822")) {                    Plotly.newPlot(                        "51452635-cf87-4b04-b05a-9a6f7cd38822",                        [{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-19 Employees","line":{"color":"rgb(102, 197, 204)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"0-19 Employees","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[97.9896800630119,100.0,88.14596286527416,93.25257958963334,108.77178859440184,101.88641124112317,102.02563094781472],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"20-49 Employees","line":{"color":"rgb(246, 207, 113)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"20-49 Employees","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[98.32591262111362,100.0,89.08048521338763,85.80282830327101,87.38109995193403,95.93747628323509,98.047319689342],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"50-249 Employees","line":{"color":"rgb(248, 156, 116)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"50-249 Employees","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[98.64590442093123,100.0,92.41287469430172,88.64617407844545,92.77421576334856,94.46642037947035,94.91778557249327],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"250-499 Employees","line":{"color":"rgb(220, 176, 242)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"250-499 Employees","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[95.33402801898806,100.0,95.5578711744047,91.3776278138904,90.78604233171791,97.00347894165192,96.05903725389659],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{fullData.name}\u003c\u002fb\u003e\u003cbr\u003eYear: %{x}\u003cbr\u003eRecovery Index (2019 = 100): %{y:.1f}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"500+ Employees","line":{"color":"rgb(135, 197, 95)","dash":"solid","width":2.5},"marker":{"symbol":"circle","size":6},"mode":"lines+markers","name":"500+ Employees","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2 ...

# %%
#in order to create a job per capita ratio we need to import ACS population data
# we first check for the column names as well, we only want to pick the absolute population values

test_acs = pd.read_csv(
    RAW_DIR / "acs" / "ACSDT5Y2018.B03002-Data.csv",
    skiprows=1
)

test_acs.columns.tolist()
# Out:
# ['Geography',
#  'Geographic Area Name',
#  'Estimate!!Total',
#  'Margin of Error!!Total',
#  'Estimate!!Total!!Not Hispanic or Latino',
#  'Margin of Error!!Total!!Not Hispanic or Latino',
#  'Estimate!!Total!!Not Hispanic or Latino!!White alone',
#  'Margin of Error!!Total!!Not Hispanic or Latino!!White alone',
#  'Estimate!!Total!!Not Hispanic or Latino!!Black or African American alone',
#  'Margin of Error!!Total!!Not Hispanic or Latino!!Black or African American alone',
#  'Estimate!!Total!!Not Hispanic or Latino!!American Indian and Alaska Native alone',
#  'Margin of Error!!Total!!Not Hispanic or Latino!!American Indian and Alaska Native alone',
#  'Estimate!!Total!!Not Hispanic or Latino!!Asian alone',
#  'Margin of Error!!Total!!Not Hispanic or Latino!!Asian alone',
#  'Estimate!!Total!!Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone',
#  'Margin of Error!!Total!!Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone',
#  'Estimate!!Total!!Not Hispanic or Latino!!Some other race alone',
#  'Margin of Error!!Total!!Not Hispanic or Latino!!Some other race alone',
#  'Estimate!!Total!!Not Hispanic or Latino!!Two or more races',
#  'Margin of Error!!Total!!Not Hispanic or Latino!!Two or more races',
#  'Estimate!!Total!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race',
#  'Margin of Error!!Total!!Not Hispanic or Latino!!Two or more races!!Two races including Some other race',
#  'Estimate!!Total!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and three or more races',
#  'Margin of Error!!Total!!Not Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and three or more races',
#  'Estimate!!Total!!Hispanic or Latino',
#  'Margin of Error!!Total!!Hispanic or Latino',
#  'Estimate!!Total!!Hispanic or Latino!!White alone',
#  'Margin of Error!!Total!!Hispanic or Latino!!White alone',
#  'Estimate!!Total!!Hispanic or Latino!!Black or African American alone',
#  'Margin of Error!!Total!!Hispanic or Latino!!Black or African American alone',
#  'Estimate!!Total!!Hispanic or Latino!!American Indian and Alaska Native alone',
#  'Margin of Error!!Total!!Hispanic or Latino!!American Indian and Alaska Native alone',
#  'Estimate!!Total!!Hispanic or Latino!!Asian alone',
#  'Margin of Error!!Total!!Hispanic or Latino!!Asian alone',
#  'Estimate!!Total!!Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone',
#  'Margin of Error!!Total!!Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone',
#  'Estimate!!Total!!Hispanic or Latino!!Some other race alone',
#  'Margin of Error!!Total!!Hispanic or Latino!!Some other race alone',
#  'Estimate!!Total!!Hispanic or Latino!!Two or more races',
#  'Margin of Error!!Total!!Hispanic or Latino!!Two or more races',
#  'Estimate!!Total!!Hispanic or Latino!!Two or more races!!Two races including Some other race',
#  'Margin of Error!!Total!!Hispanic or Latino!!Two or more races!!Two races including Some other race',
#  'Estimate!!Total!!Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and three or more races',
#  'Margin of Error!!Total!!Hispanic or Latino!!Two or more races!!Two races excluding Some other race, and three or more races',
#  'Unnamed: 44']

# %%
#cleans by keeping only the columns we need. not taking into consideration the margins of error for this analysis.
acs = test_acs[[
    "Geographic Area Name",
    "Estimate!!Total",
    "Estimate!!Total!!Not Hispanic or Latino!!White alone",
    "Estimate!!Total!!Not Hispanic or Latino!!Black or African American alone",
    "Estimate!!Total!!Not Hispanic or Latino!!American Indian and Alaska Native alone",
    "Estimate!!Total!!Not Hispanic or Latino!!Asian alone",
    "Estimate!!Total!!Hispanic or Latino"
]].copy()

# %%
# change column names in a way that we can easily read it and interpret
acs = acs.rename(columns={
    "Geographic Area Name": "county",
    "Estimate!!Total": "pop_total",
    "Estimate!!Total!!Not Hispanic or Latino!!White alone": "pop_white",
    "Estimate!!Total!!Not Hispanic or Latino!!Black or African American alone": "pop_black",
    "Estimate!!Total!!Not Hispanic or Latino!!American Indian and Alaska Native alone": "pop_native",
    "Estimate!!Total!!Not Hispanic or Latino!!Asian alone": "pop_asian",
    "Estimate!!Total!!Hispanic or Latino": "pop_hispanic"
})

acs.head()
# Out:
#                              county  pop_total  pop_white  pop_black  \
# 0        Alameda County, California    1643700     523391     172329
# 1   Contra Costa County, California    1133247     502951      93683
# 2          Marin County, California     260295     185809       5597
# 3           Napa County, California     140530      74159       2764
# 4  San Francisco County, California     870044     353670      43619
#
#    pop_native  pop_asian  pop_hispanic
# 0        5288     483067        369061
# 1        2376     182135        288101
# 2         435      14815         41335
# 3         326      11210         47687
# 4        1363     294846        132651

# %%
# this is just one year (2018), we add the year so that we can later group these by year
acs["year"] = 2018

# %%
# clean the county names so that they match our other dataframes's format
acs["county_clean"] = (acs["county"].str.replace(" County, California", "", regex=False))
# + ", CA")

# %%
# we drop extra column after fixing column names for county
acs = acs.drop(['county'], axis=1)

# %%
acs.head()
# Out:
#    pop_total  pop_white  pop_black  pop_native  pop_asian  pop_hispanic  year  \
# 0    1643700     523391     172329        5288     483067        369061  2018
# 1    1133247     502951      93683        2376     182135        288101  2018
# 2     260295     185809       5597         435      14815         41335  2018
# 3     140530      74159       2764         326      11210         47687  2018
# 4     870044     353670      43619        1363     294846        132651  2018
#
#     county_clean
# 0        Alameda
# 1   Contra Costa
# 2          Marin
# 3           Napa
# 4  San Francisco

# %%
# for safety we convert to numeric (function)
for col in ["pop_total", "pop_white", "pop_black", "pop_native", "pop_asian", "pop_hispanic"]:
    acs[col] = pd.to_numeric(acs[col], errors="coerce")

# %%
print(acs.dtypes)
# Out:
# pop_total        int64
# pop_white        int64
# pop_black        int64
# pop_native       int64
# pop_asian        int64
# pop_hispanic     int64
# year             int64
# county_clean    object
# dtype: object

# %%
print(acs.head())
# Out:
#    pop_total  pop_white  pop_black  pop_native  pop_asian  pop_hispanic  year  \
# 0    1643700     523391     172329        5288     483067        369061  2018
# 1    1133247     502951      93683        2376     182135        288101  2018
# 2     260295     185809       5597         435      14815         41335  2018
# 3     140530      74159       2764         326      11210         47687  2018
# 4     870044     353670      43619        1363     294846        132651  2018
#
#     county_clean
# 0        Alameda
# 1   Contra Costa
# 2          Marin
# 3           Napa
# 4  San Francisco

# %%
acs_2018 = acs[[
    "county_clean",
    "pop_total",
    "pop_white",
    "pop_black",
    "pop_native",
    "pop_asian",
    "pop_hispanic",
    "year"
]].copy()

# %%
acs_2018.head()
# Out:
#     county_clean  pop_total  pop_white  pop_black  pop_native  pop_asian  \
# 0        Alameda    1643700     523391     172329        5288     483067
# 1   Contra Costa    1133247     502951      93683        2376     182135
# 2          Marin     260295     185809       5597         435      14815
# 3           Napa     140530      74159       2764         326      11210
# 4  San Francisco     870044     353670      43619        1363     294846
#
#    pop_hispanic  year
# 0        369061  2018
# 1        288101  2018
# 2         41335  2018
# 3         47687  2018
# 4        132651  2018

# %%
# this seemed to have worked for 2018, let's repeat for the remaining years so that then we can merge all these together in one single ACS df
acs_folder = RAW_DIR / "acs"
years = [2019, 2020, 2021, 2022, 2023, 2024]

acs_list = []

for year in years:
    file_path = acs_folder / f"ACSDT5Y{year}.B03002-Data.csv"

    df = pd.read_csv(file_path, skiprows=1)

    df = df[[
        "Geographic Area Name",
        "Estimate!!Total:",
        "Estimate!!Total:!!Not Hispanic or Latino:!!White alone",
        "Estimate!!Total:!!Not Hispanic or Latino:!!Black or African American alone",
        "Estimate!!Total:!!Not Hispanic or Latino:!!American Indian and Alaska Native alone",
        "Estimate!!Total:!!Not Hispanic or Latino:!!Asian alone",
        "Estimate!!Total:!!Hispanic or Latino:"
    ]].copy()

    df = df.rename(columns={
        "Geographic Area Name": "county",
        "Estimate!!Total:": "pop_total",
        "Estimate!!Total:!!Not Hispanic or Latino:!!White alone": "pop_white",
        "Estimate!!Total:!!Not Hispanic or Latino:!!Black or African American alone": "pop_black",
        "Estimate!!Total:!!Not Hispanic or Latino:!!American Indian and Alaska Native alone": "pop_native",
        "Estimate!!Total:!!Not Hispanic or Latino:!!Asian alone": "pop_asian",
        "Estimate!!Total:!!Hispanic or Latino:": "pop_hispanic"
    })

    df["county_clean"] = df["county"].str.replace(" County, California", "", regex=False)
    df["year"] = year

    for col in ["pop_total", "pop_white", "pop_black", "pop_native", "pop_asian","pop_hispanic"]:
        df[col] = pd.to_numeric(df[col], errors="coerce")

    acs_list.append(df)

# %%
# concatenating these all together as mentioned above
acs_2019_2024 = pd.concat(acs_list, ignore_index=True)

acs_2019_2024.head()
acs_2019_2024.shape
# Out:
# (54, 9)

# %%
acs_all_df = pd.concat(
    [acs_2018, acs_2019_2024],
    ignore_index=True
)

# %%
# we drop extra column after fixing column names for county for the same reason as before
acs_all_df = acs_all_df.drop(['county'], axis=1)

# %%
acs_all_df.head(10)
# Out:
#     county_clean  pop_total  pop_white  pop_black  pop_native  pop_asian  \
# 0        Alameda    1643700     523391     172329        5288     483067
# 1   Contra Costa    1133247     502951      93683        2376     182135
# 2          Marin     260295     185809       5597         435      14815
# 3           Napa     140530      74159       2764         326      11210
# 4  San Francisco     870044     353670      43619        1363     294846
# 5      San Mateo     765935     303047      16838        1151     212474
# 6    Santa Clara    1922200     615912      45379        3003     685265
# 7         Solano     438530     168870      59500        1258      65994
# 8         Sonoma     501317     318237       7192        2068      19720
# 9        Alameda    1656754     520447     171168        5210     496006
#
#    pop_hispanic  year
# 0        369061  2018
# 1        288101  2018
# 2         41335  2018
# 3         47687  2018
# 4        132651  2018
# 5        189002  2018
# 6        495455  2018
# 7        114406  2018
# 8        132985  2018
# 9        371019  2019

# %%
# check if we have any missing values - sanity check
acs_all_df.isnull().sum().sort_values(ascending=False)
# Out:
# county_clean    0
# pop_total       0
# pop_white       0
# pop_black       0
# pop_native      0
# pop_asian       0
# pop_hispanic    0
# year            0
# dtype: int64

# %%
# convert years into datetime as our df_race uses datetime (not necessary but consistent with the rest of the code)
acs_all_df["year_pd"] = pd.to_datetime(acs_all_df["year"], format="%Y")

# %%
acs_all_df = acs_all_df.drop(columns=["year"])

# %%
acs_all_df.head()
# Out:
#     county_clean  pop_total  pop_white  pop_black  pop_native  pop_asian  \
# 0        Alameda    1643700     523391     172329        5288     483067
# 1   Contra Costa    1133247     502951      93683        2376     182135
# 2          Marin     260295     185809       5597         435      14815
# 3           Napa     140530      74159       2764         326      11210
# 4  San Francisco     870044     353670      43619        1363     294846
#
#    pop_hispanic    year_pd
# 0        369061 2018-01-01
# 1        288101 2018-01-01
# 2         41335 2018-01-01
# 3         47687 2018-01-01
# 4        132651 2018-01-01

# %%
print(acs_all_df.dtypes)
# Out:
# county_clean            object
# pop_total                int64
# pop_white                int64
# pop_black                int64
# pop_native               int64
# pop_asian                int64
# pop_hispanic             int64
# year_pd         datetime64[ns]
# dtype: object

# %%
acs_all_df = acs_all_df.rename(columns={"county_clean": "county"})

# %%
acs_all_df.columns
# Out:
# Index(['county', 'pop_total', 'pop_white', 'pop_black', 'pop_native',
#        'pop_asian', 'pop_hispanic', 'year_pd'],
#       dtype='object')

# %%
# filter for all firm size only
df_totals = df_totals[
    df_totals["firmsize"] == 0
].copy()

# %%
# let us now merge the two (employment & ACS data) so to compute later the Jobs per capita index
df_totals = df_totals.merge(
    acs_all_df,
    on=["county", "year_pd"],
    how="left"
)

df_totals.head()
# Out:
#      year_pd  firmsize firmsize_label_value  n_employed  baseline_emp  \
# 0 2018-01-01         0       All Firm Sizes    624186.0      633617.0
# 1 2019-01-01         0       All Firm Sizes    633617.0      633617.0
# 2 2020-01-01         0       All Firm Sizes    592027.0      633617.0
# 3 2021-01-01         0       All Firm Sizes    597503.0      633617.0
# 4 2022-01-01         0       All Firm Sizes    628668.0      633617.0
#
#    recovery_index_all   county  pop_total  pop_white  pop_black  pop_native  \
# 0           98.511561  Alameda    1643700     523391     172329        5288
# 1          100.000000  Alameda    1656754     520447     171168        5210
# 2           93.436098  Alameda    1661584     508583     167316        4942
# 3           94.300342  Alameda    1673133     499730     166017        5248
# 4           99.218929  Alameda    1663823     487452     165390        4870
#
#    pop_asian  pop_hispanic
# 0     483067        369061
# 1     496006        371019
# 2     515105        369546
# 3     524980        374542
# 4     530999        369603

# %%
df_totals.isnull().sum().sort_values(ascending=False)
# Out:
# year_pd                 0
# firmsize                0
# firmsize_label_value    0
# n_employed              0
# baseline_emp            0
# recovery_index_all      0
# county                  0
# pop_total               0
# pop_white               0
# pop_black               0
# pop_native              0
# pop_asian               0
# pop_hispanic            0
# dtype: int64

# %%
# compute job per capita for df_totals
df_totals["jobs_per_capita"] = df_totals["n_employed"] / df_totals["pop_total"]

df_totals.head()
# Out:
#      year_pd  firmsize firmsize_label_value  n_employed  baseline_emp  \
# 0 2018-01-01         0       All Firm Sizes    624186.0      633617.0
# 1 2019-01-01         0       All Firm Sizes    633617.0      633617.0
# 2 2020-01-01         0       All Firm Sizes    592027.0      633617.0
# 3 2021-01-01         0       All Firm Sizes    597503.0      633617.0
# 4 2022-01-01         0       All Firm Sizes    628668.0      633617.0
#
#    recovery_index_all   county  pop_total  pop_white  pop_black  pop_native  \
# 0           98.511561  Alameda    1643700     523391     172329        5288
# 1          100.000000  Alameda    1656754     520447     171168        5210
# 2           93.436098  Alameda    1661584     508583     167316        4942
# 3           94.300342  Alameda    1673133     499730     166017        5248
# 4           99.218929  Alameda    1663823     487452     165390        4870
#
#    pop_asian  pop_hispanic  jobs_per_capita
# 0     483067        369061         0.379744
# 1     496006        371019         0.382445
# 2     515105        369546         0.356303
# 3     524980        374542         0.357116
# 4     530999        369603         0.377845

# %%
df_totals["pop_total"].isna().sum()
# Out:
# np.int64(0)

# %%
# we now want to save this into our processed folder
df_totals.to_csv(
    PROCESSED_DIR / "df_totals_cleaned.csv",
    index=False
)

# %%
# let us first plot jobs_per_capita by county
df_totals_plot = df_totals.copy()

# %%
# deleting duplicates and making a copy just in case we need it later
pop_trends = df_totals[["county", "year_pd", "pop_total"]].drop_duplicates().copy()

pop_trends.head()
# Out:
#     county    year_pd  pop_total
# 0  Alameda 2018-01-01    1643700
# 1  Alameda 2019-01-01    1656754
# 2  Alameda 2020-01-01    1661584
# 3  Alameda 2021-01-01    1673133
# 4  Alameda 2022-01-01    1663823

# %%
df_totals.columns.tolist()
# Out:
# ['year_pd',
#  'firmsize',
#  'firmsize_label_value',
#  'n_employed',
#  'baseline_emp',
#  'recovery_index_all',
#  'county',
#  'pop_total',
#  'pop_white',
#  'pop_black',
#  'pop_native',
#  'pop_asian',
#  'pop_hispanic',
#  'jobs_per_capita']

# %%
# we want to plot jobs per capita by county, highlighting Alameda and San Francisco, we apply Function 3
fig = plot_trends(
    df=df_totals_plot,
    x_col="year_pd",
    y_col="jobs_per_capita",
    county_col="county",
    title="Jobs per Capita by County (Bay Area)",
    ylabel="Jobs per Capita (total jobs / total population)",
    save_path="visualizations/jobs_capita_county.png",
    figsize=(8, 6),
    legend_title="Counties:",
    y_min=0,
    start_groups=["Alameda", "San Francisco"]  #highlighting two counties at the start
)
fig.write_html(
    VIS_DIR / "jobs_capita_county.html"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="451fef3d-e741-44a6-a88a-7bdddb5e65f8" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("451fef3d-e741-44a6-a88a-7bdddb5e65f8")) {                    Plotly.newPlot(                        "451fef3d-e741-44a6-a88a-7bdddb5e65f8",                        [{"hovertemplate":"Counties:=Alameda\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total jobs \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alameda","line":{"color":"rgb(102, 197, 204)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Alameda","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.37974447891951085,0.38244482886415243,0.35630278096081813,0.3571162603331594,0.3778454799579042,0.39293101663550145,0.3974293607715919],"yaxis":"y","type":"scatter"},{"hovertemplate":"Counties:=Contra Costa\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total jobs \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Contra Costa","line":{"color":"rgb(246, 207, 113)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Contra Costa","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.26343947965447956,0.26430968324825277,0.24734881354396457,0.24713272494217242,0.2582028266508866,0.2641602193105562,0.2633432101986932],"yaxis":"y","type":"scatter","visible":"legendonly"},{"hovertemplate":"Counties:=Marin\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total jobs \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Marin","line":{"color":"rgb(248, 156, 116)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Marin","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.3292994487024338,0.3291336946946061,0.3035757648174344,0.3042262002309566,0.31890128030404824,0.32739358104844163,0.33456733173365794],"yaxis":"y","type":"scatter","visible":"legendonly"},{"hovertemplate":"Counties:=Napa\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total jobs \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Napa","line":{"color":"rgb(220, 176, 242)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Napa","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.3960506653383619,0.41430853082944785,0.38350460410472537,0.3682049065168054,0.40354044139055495,0.42472991842434044,0.4399973307431656],"yaxis":"y","type":"scatter","visible":"legendonly"},{"hovertemplate":"Counties:=San Francisco\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total jobs \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"San Francisco","line":{"color":"rgb(135, 197, 95)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"San Francisco","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.645496089852927,0.66673600 ...

# %%
# importing the county shape file so we can make a map

import geopandas as gpd

gdf = gpd.read_file(
    RAW_DIR / "shapefiles" / "California counties" / "Counties.shp"
)

# %%
# SECTION 3

######

# CHOROPLETH MAPS - let us import TIGERLINE shapefiles to create a map

######
import geopandas as gpd
gdf = gpd.read_file(
    RAW_DIR / "shapefiles" / "California counties" / "Counties.shp"
)

# %%
gdf.columns
# Out:
# Index(['Year', 'CountyName', 'COUNTY_FIP', 'DistrictCo', 'geometry'], dtype='object')

# %%
gdf.head()
# Out:
#    Year CountyName COUNTY_FIP  DistrictCo  \
# 0  2023    Alameda        001          22
# 1  2023     Alpine        003           2
# 2  2023     Amador        005           2
# 3  2023     Colusa        011           5
# 4  2023  El Dorado        017          16
#
#                                             geometry
# 0  MULTIPOLYGON (((-13577345.444 4504491.196, -13...
# 1  POLYGON ((-13312191.387 4680675.259, -13312135...
# 2  POLYGON ((-13366398.979 4679185.227, -13366398...
# 3  POLYGON ((-13568735.664 4776807.645, -13568728...
# 4  POLYGON ((-13347688.733 4712126.051, -13347699...

# %%
# COUNTY TOTAL CHOROPLETH MAP
map_df = df_totals[df_totals["year_pd"].dt.year == 2024].copy() # for 2024, create a dataframe which is equal to total employments.

# %%
# we keep only the two columns of interest
map_df[["county", "recovery_index_all"]]
# Out:
#            county  recovery_index_all
# 6         Alameda          103.461397
# 13   Contra Costa          101.619699
# 20          Marin          100.878956
# 27           Napa          102.584404
# 34  San Francisco           96.572147
# 41      San Mateo          102.044642
# 48    Santa Clara          105.065318
# 55         Solano          103.061769
# 62         Sonoma          101.555955

# %%
# from the tiger line shapefiles we want to keep only the counties we are interested in
bay_counties = map_df["county"].unique().tolist()
bay_gdf = gdf[gdf["CountyName"].isin(bay_counties)].copy()

bay_gdf[["CountyName"]]
# Out:
#        CountyName
# 0         Alameda
# 21  San Francisco
# 26         Solano
# 27         Sonoma
# 36   Contra Costa
# 42          Marin
# 45           Napa
# 50      San Mateo
# 52    Santa Clara

# %%
# merge the shapefiles with the map_df so to connect the shapefiles with the results
bay_gdf = bay_gdf.merge(
    map_df[["county", "recovery_index_all"]],
    left_on="CountyName",
    right_on="county",
    how="left"
)

bay_gdf[["CountyName", "recovery_index_all"]]
# Out:
#       CountyName  recovery_index_all
# 0        Alameda          103.461397
# 1  San Francisco           96.572147
# 2         Solano          103.061769
# 3         Sonoma          101.555955
# 4   Contra Costa          101.619699
# 5          Marin          100.878956
# 6           Napa          102.584404
# 7      San Mateo          102.044642
# 8    Santa Clara          105.065318

# %%
# we now want to plot our recovery index by county. We first need to import some of the dependencies that we also used in our helper file since this is not a function
import json
import plotly.express as px

# convert GeoDataFrame to latitude/longitude CRS required by Plotly
bay_plot = bay_gdf.to_crs("EPSG:4326").reset_index(drop=True)
# create unique ID for each county polygon
bay_plot["id"] = bay_plot.index
# convert GeoDataFrame into GeoJSON format for Plotly
geojson = json.loads(bay_plot.to_json())

# create interactive choropleth map
fig = px.choropleth(
    # dataframe containing geometry + recovery values
    bay_plot,
    geojson=geojson,
    locations="id", #tells Plotly which dataframe column contains polygon IDs.
    featureidkey="properties.id", # tells Plotly where the matching IDs live inside the GeoJSON.
    color="recovery_index_all",
    color_continuous_scale="PiYG",
    color_continuous_midpoint=100,
    hover_name="CountyName",
    hover_data={"recovery_index_all": ":.0f"},
    title="Bay Area County Recovery Index 2024 (all races)",
    labels={"recovery_index_all": "Recovery Index (2019 = 100)"}
)

fig.update_geos(
    visible=False,
    fitbounds="locations",
    projection_scale=12.5,
    center={"lat": 37.7, "lon": -122.2}
)

fig.update_layout(        #formatting things
    font_family="Georgia",
    paper_bgcolor="white",
    margin=dict(l=0, r=0, t=40, b=0),
    coloraxis_colorbar=dict(len=0.8)
)

# save interactive html for ArcGIS StoryMaps
fig.write_html(VIS_DIR / "recovery_index_county_map_2024.html")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="45b318d6-073b-4bc2-b9de-3a4cecb4df7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45b318d6-073b-4bc2-b9de-3a4cecb4df7a")) {                    Plotly.newPlot(                        "45b318d6-073b-4bc2-b9de-3a4cecb4df7a",                        [{"coloraxis":"coloraxis","customdata":[[103.46139702691057],[96.5721465695753],[103.06176889029402],[101.55595451825255],[101.61969871616519],[100.87895647295339],[102.58440368558439],[102.04464162398776],[105.06531760200049]],"featureidkey":"properties.id","geo":"geo","geojson":{"type":"FeatureCollection","features":[{"id":"0","type":"Feature","properties":{"Year":"2023","CountyName":"Alameda","COUNTY_FIP":"001","DistrictCo":22,"county":"Alameda","recovery_index_all":103.46139702691057,"id":0},"geometry":{"type":"MultiPolygon","coordinates":[[[[-121.96736930228089,37.467635848984735],[-121.96836830322923,37.463138848696374],[-121.97327430208085,37.46183784800137],[-121.97467030223918,37.461539848364],[-121.97567030272941,37.461639848876665],[-121.98696930259952,37.46353884805977],[-121.99176730303049,37.465037848657836],[-121.98737330191837,37.464740848050354],[-121.98516830249332,37.465240848071865],[-121.97797430208323,37.46983684828434],[-121.97507430266984,37.46903584886103],[-121.97406730190828,37.4687388486256],[-121.97287030305381,37.46853684884181],[-121.96736930228089,37.467635848984735]]],[[[-122.24607830207968,37.781325849451065],[-122.24597930281418,37.77892684876487],[-122.24777930301346,37.77912884838288],[-122.2546763028246,37.785327848298124],[-122.25287630303819,37.78582784968142],[-122.24938230286705,37.78432884981645],[-122.24607830207968,37.781325849451065]]],[[[-122.29824030288286,37.79086684810824],[-122.2948833030802,37.79082884893254],[-122.29387630275136,37.79112684907201],[-122.2908783024229,37.792026849290075],[-122.29058130356881,37.79092784907755],[-122.29028330277455,37.792026848945554],[-122.28987930326429,37.79092784885791],[-122.28958130241317,37.79232784900338],[-122.28917630330248,37.79092784922755],[-122.28868130273835,37.79242684901521],[-122.28838330203415,37.79092784843075],[-122.28788030237443,37.792526848502376],[-122.28067730394366,37.792628849031075],[-122.27728230178774,37.79182784765053],[-122.27707630253951,37.79152684891602],[-122.27597830219224,37.790427848923116],[-122.27545130211689,37.79077884933263],[-122.27538330335254,37.79082884904667],[-122.27487930330437,37.789226848959586],[-122.2716823027047,37.78802884905771],[-122.26898230282217,37.78642684904386],[-122.27037830191277,37.78702884768242],[-122.26936330359051,37.78570184917819],[-122.26908130269459,37.78532784775367],[-122.26878330311426,37.78352784860001],[-122.268486302425,37.783618848737284],[-122.26693730257472,37.78409584898595],[-122.26618130301536,37.78432884959271],[-122.26589930304098,37.7842288491368],[-122.2655793030047,37.78411884900965],[-122.26448030448759,37.7837298485101],[-122.26287830221771,37.78272584926624],[-122.2624203036599,37.782798849250156],[-122.26158130355181,37.782928848757145],[-122.26148230251748,37.778327848928036],[-122.26087930361837,37.77812984901251],[-122.25997930336835,37.78262684945153],[-122.25717930261293,37.781226848216505],[-122.25878130311904,37.77862884868954],[-122.25688130371634,37.7775268485178],[-122.25488230271893,37.78042984895235],[-122.25537830335618,37.7790298485183],[-122.25208330303289,37.778426848476684],[-122.25157930271632,37.77862884903039],[-122.25058030460974,37.7766268489391],[-122.24828330272179,37.77552784874251],[-122.24427830296341,37.77512784764044],[-122.23887630301364,37.77202984894966],[-122.23677830250239,37.771026847997966],[-122.23507730451392,37.77032884829421],[-122.23174330290928,37.768817 ...

# %%
county_df.head()
# Out:
#   geo_level geo_level_label_value  geography geography_label_value ind_level  \
# 0         C              Counties       6001           Alameda, CA         A
# 1         C              Counties       6001           Alameda, CA         A
# 2         C              Counties       6001           Alameda, CA         A
# 3         C              Counties       6001           Alameda, CA         A
# 4         C              Counties       6001           Alameda, CA         A
#
#   industry industry_label_value ownercode ownercode_label_value race  \
# 0       00    All NAICS Sectors       A05           All Private   A0
# 1       00    All NAICS Sectors       A05           All Private   A0
# 2       00    All NAICS Sectors       A05           All Private   A0
# 3       00    All NAICS Sectors       A05           All Private   A1
# 4       00    All NAICS Sectors       A05           All Private   A1
#
#   race_label_value ethnicity   ethnicity_label_value  firmsize  \
# 0        All Races        A0         All Ethnicities         0
# 1        All Races        A1  Not Hispanic or Latino         0
# 2        All Races        A2      Hispanic or Latino         0
# 3      White Alone        A0         All Ethnicities         0
# 4      White Alone        A1  Not Hispanic or Latino         0
#
#   firmsize_label_value  agg_level     year_pd  n_employed
# 0       All Firm Sizes       4129  2018-01-01    624186.0
# 1       All Firm Sizes       4137  2018-01-01    472770.0
# 2       All Firm Sizes       4137  2018-01-01    151416.0
# 3       All Firm Sizes       4133  2018-01-01    360841.0
# 4       All Firm Sizes       4141  2018-01-01    233414.0

# %%
######### SECTION 4 ################


# COUNTY BY RACE



####################

df_race = county_df[
    (county_df["industry"] == "00") & # all industries filtered
    (county_df["race"] != "A0") & # this time race is not filtered to all as we are interested in this variable now
    (county_df["ownercode"] == "A05") &
    (county_df["firmsize"] == 0) &
    (county_df["ethnicity"] == "A0")  #this time ethnicity is not filtered yet
].copy()

# %%
# transform year in datetime. we know this is not necessary but we keeep it consistent as it might be useful in the future
df_race["year_pd"] = pd.to_datetime(df_race["year_pd"])

# %%
# drop missing employment before grouping
df_race = df_race.dropna(subset=["n_employed"])

# %%
# adjust county names from San Francisco, CA to San Francisco to mantain consistency
df_race["county"] = df_race["geography_label_value"].str.replace(", CA", "", regex=False)

# %%
# merge df_race with acs_all_df so to calculate jobs per capita
df_race = df_race.merge(
    acs_all_df,
    on=["county", "year_pd"],
    how="left"
)

df_race.head()
# Out:
#   geo_level geo_level_label_value  geography geography_label_value ind_level  \
# 0         C              Counties       6001           Alameda, CA         A
# 1         C              Counties       6001           Alameda, CA         A
# 2         C              Counties       6001           Alameda, CA         A
# 3         C              Counties       6001           Alameda, CA         A
# 4         C              Counties       6001           Alameda, CA         A
#
#   industry industry_label_value ownercode ownercode_label_value race  ...  \
# 0       00    All NAICS Sectors       A05           All Private   A1  ...
# 1       00    All NAICS Sectors       A05           All Private   A2  ...
# 2       00    All NAICS Sectors       A05           All Private   A3  ...
# 3       00    All NAICS Sectors       A05           All Private   A4  ...
# 4       00    All NAICS Sectors       A05           All Private   A5  ...
#
#   agg_level    year_pd n_employed   county pop_total  pop_white pop_black  \
# 0      4133 2018-01-01   360841.0  Alameda   1643700     523391    172329
# 1      4133 2018-01-01    57709.0  Alameda   1643700     523391    172329
# 2      4133 2018-01-01     7701.0  Alameda   1643700     523391    172329
# 3      4133 2018-01-01   167632.0  Alameda   1643700     523391    172329
# 4      4133 2018-01-01     5581.0  Alameda   1643700     523391    172329
#
#    pop_native pop_asian  pop_hispanic
# 0        5288    483067        369061
# 1        5288    483067        369061
# 2        5288    483067        369061
# 3        5288    483067        369061
# 4        5288    483067        369061
#
# [5 rows x 25 columns]

# %%
dup_check = (
    df_race.groupby(["geography_label_value", "race", "year_pd", "ethnicity"])
    .size()
    .reset_index(name="n_rows")
    .sort_values("n_rows", ascending=False)
)

dup_check.head(10)
# Out:
#     geography_label_value race    year_pd ethnicity  n_rows
# 377            Sonoma, CA   A7 2024-01-01        A0       1
# 0             Alameda, CA   A1 2018-01-01        A0       1
# 1             Alameda, CA   A1 2019-01-01        A0       1
# 2             Alameda, CA   A1 2020-01-01        A0       1
# 3             Alameda, CA   A1 2021-01-01        A0       1
# 4             Alameda, CA   A1 2022-01-01        A0       1
# 5             Alameda, CA   A1 2023-01-01        A0       1
# 6             Alameda, CA   A1 2024-01-01        A0       1
# 7             Alameda, CA   A2 2018-01-01        A0       1
# 8             Alameda, CA   A2 2019-01-01        A0       1

# %%
# check races names so to check they are all there
df_race[["race", "race_label_value"]].drop_duplicates().sort_values("race")
# Out:
#   race                                 race_label_value
# 0   A1                                      White Alone
# 1   A2                  Black or African American Alone
# 2   A3           American Indian or Alaska Native Alone
# 3   A4                                      Asian Alone
# 4   A5  Native Hawaiian or Other Pacific Islander Alone
# 5   A7                          Two or More Race Groups

# %%
# using Function 4 (map_race_population) to assign population estimates for each race category
# we focus only on A1-A4 as the other races did not have enough data to provide meaningful insights.
# hispanic population is treated separately as considered Ethnicity by the ACS census
race_map = {
    "A1": "pop_white",
    "A2": "pop_black",
    "A3": "pop_native",
    "A4": "pop_asian",
}

df_race = map_race_population(df_race, race_map=race_map)

# %%
df_race.head()
# Out:
#   geo_level geo_level_label_value  geography geography_label_value ind_level  \
# 0         C              Counties       6001           Alameda, CA         A
# 1         C              Counties       6001           Alameda, CA         A
# 2         C              Counties       6001           Alameda, CA         A
# 3         C              Counties       6001           Alameda, CA         A
# 4         C              Counties       6001           Alameda, CA         A
#
#   industry industry_label_value ownercode ownercode_label_value race  ...  \
# 0       00    All NAICS Sectors       A05           All Private   A1  ...
# 1       00    All NAICS Sectors       A05           All Private   A2  ...
# 2       00    All NAICS Sectors       A05           All Private   A3  ...
# 3       00    All NAICS Sectors       A05           All Private   A4  ...
# 4       00    All NAICS Sectors       A05           All Private   A5  ...
#
#      year_pd n_employed   county  pop_total pop_white  pop_black pop_native  \
# 0 2018-01-01   360841.0  Alameda    1643700    523391     172329       5288
# 1 2018-01-01    57709.0  Alameda    1643700    523391     172329       5288
# 2 2018-01-01     7701.0  Alameda    1643700    523391     172329       5288
# 3 2018-01-01   167632.0  Alameda    1643700    523391     172329       5288
# 4 2018-01-01     5581.0  Alameda    1643700    523391     172329       5288
#
#    pop_asian pop_hispanic  population_by_race
# 0     483067       369061              523391
# 1     483067       369061              172329
# 2     483067       369061                5288
# 3     483067       369061              483067
# 4     483067       369061                None
#
# [5 rows x 26 columns]

# %%
# check that the assignment worked

df_race[[
    "county", "race", "race_label_value",
    "pop_white", "pop_black", "pop_native", "pop_asian",
    "population_by_race"
]].head(15)
# Out:
#           county race                                 race_label_value  \
# 0        Alameda   A1                                      White Alone
# 1        Alameda   A2                  Black or African American Alone
# 2        Alameda   A3           American Indian or Alaska Native Alone
# 3        Alameda   A4                                      Asian Alone
# 4        Alameda   A5  Native Hawaiian or Other Pacific Islander Alone
# 5        Alameda   A7                          Two or More Race Groups
# 6   Contra Costa   A1                                      White Alone
# 7   Contra Costa   A2                  Black or African American Alone
# 8   Contra Costa   A3           American Indian or Alaska Native Alone
# 9   Contra Costa   A4                                      Asian Alone
# 10  Contra Costa   A5  Native Hawaiian or Other Pacific Islander Alone
# 11  Contra Costa   A7                          Two or More Race Groups
# 12         Marin   A1                                      White Alone
# 13         Marin   A2                  Black or African American Alone
# 14         Marin   A3           American Indian or Alaska Native Alone
#
#     pop_white  pop_black  pop_native  pop_asian population_by_race
# 0      523391     172329        5288     483067             523391
# 1      523391     172329        5288     483067             172329
# 2      523391     172329        5288     483067               5288
# 3      523391     172329        5288     483067             483067
# 4      523391     172329        5288     483067               None
# 5      523391     172329        5288     483067               None
# 6      502951      93683        2376     182135             502951
# 7      502951      93683        2376     182135              93683
# 8      502951      93683        2376     182135               2376
# 9      502951      93683        2376     182135             182135
# 10     502951      93683        2376     182135               None
# 11     502951      93683        2376     182135               None
# 12     185809       5597         435      14815             185809
# 13     185809       5597         435      14815               5597
# 14     185809       5597         435      14815                435

# %%
# we can build our baseline (2019) with Function 1
df_race = add_baseline(
    df_race,
    value_col="n_employed",
    baseline_year=2019,
    group_cols=["county", "race"],
    baseline_col="baseline_emp_race"
)

# %%
# recovery index calculation by race using function 2
df_race = add_recovery_index(
    df_race,
    current_col="n_employed",
    baseline_col="baseline_emp_race",
    recovery_col="recovery_index_race"
)

# %%
df_race.head()
# Out:
#   geo_level geo_level_label_value  geography geography_label_value ind_level  \
# 0         C              Counties       6001           Alameda, CA         A
# 1         C              Counties       6001           Alameda, CA         A
# 2         C              Counties       6001           Alameda, CA         A
# 3         C              Counties       6001           Alameda, CA         A
# 4         C              Counties       6001           Alameda, CA         A
#
#   industry industry_label_value ownercode ownercode_label_value race  ...  \
# 0       00    All NAICS Sectors       A05           All Private   A1  ...
# 1       00    All NAICS Sectors       A05           All Private   A2  ...
# 2       00    All NAICS Sectors       A05           All Private   A3  ...
# 3       00    All NAICS Sectors       A05           All Private   A4  ...
# 4       00    All NAICS Sectors       A05           All Private   A5  ...
#
#     county pop_total pop_white  pop_black pop_native  pop_asian pop_hispanic  \
# 0  Alameda   1643700    523391     172329       5288     483067       369061
# 1  Alameda   1643700    523391     172329       5288     483067       369061
# 2  Alameda   1643700    523391     172329       5288     483067       369061
# 3  Alameda   1643700    523391     172329       5288     483067       369061
# 4  Alameda   1643700    523391     172329       5288     483067       369061
#
#    population_by_race baseline_emp_race  recovery_index_race
# 0              523391          363884.0            99.163744
# 1              172329           58681.0            98.343587
# 2                5288            8013.0            96.106327
# 3              483067          171851.0            97.544966
# 4                None            5707.0            97.792185
#
# [5 rows x 28 columns]

# %%
# let's drop the missing population_by_race before computing jobs per capita
# we create a new df because otherwise we would lose data for future work (original is df_race)
df_race_plot = df_race.dropna(subset=["population_by_race"])

# %%
df_race_plot[[
    "county", "race", "race_label_value",
    "pop_white", "pop_black", "pop_native", "pop_asian",
    "population_by_race", "n_employed"
]].head(15)
# Out:
#           county race                        race_label_value  pop_white  \
# 0        Alameda   A1                             White Alone     523391
# 1        Alameda   A2         Black or African American Alone     523391
# 2        Alameda   A3  American Indian or Alaska Native Alone     523391
# 3        Alameda   A4                             Asian Alone     523391
# 6   Contra Costa   A1                             White Alone     502951
# 7   Contra Costa   A2         Black or African American Alone     502951
# 8   Contra Costa   A3  American Indian or Alaska Native Alone     502951
# 9   Contra Costa   A4                             Asian Alone     502951
# 12         Marin   A1                             White Alone     185809
# 13         Marin   A2         Black or African American Alone     185809
# 14         Marin   A3  American Indian or Alaska Native Alone     185809
# 15         Marin   A4                             Asian Alone     185809
# 18          Napa   A1                             White Alone      74159
# 19          Napa   A2         Black or African American Alone      74159
# 20          Napa   A3  American Indian or Alaska Native Alone      74159
#
#     pop_black  pop_native  pop_asian population_by_race  n_employed
# 0      172329        5288     483067             523391    360841.0
# 1      172329        5288     483067             172329     57709.0
# 2      172329        5288     483067               5288      7701.0
# 3      172329        5288     483067             483067    167632.0
# 6       93683        2376     182135             502951    197550.0
# 7       93683        2376     182135              93683     24567.0
# 8       93683        2376     182135               2376      3682.0
# 9       93683        2376     182135             182135     58412.0
# 12       5597         435      14815             185809     63818.0
# 13       5597         435      14815               5597      5110.0
# 14       5597         435      14815                435      1079.0
# 15       5597         435      14815              14815     12066.0
# 18       2764         326      11210              74159     45034.0
# 19       2764         326      11210               2764      2608.0
# 20       2764         326      11210                326       838.0

# %%
#calculate jobs_per_capita with the races available
df_race_plot["jobs_per_capita"] = df_race["n_employed"] / df_race["population_by_race"]
# Out:
# /tmp/ipykernel_6839/3858050838.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_race_plot[["county", "race_label_value","n_employed","population_by_race","jobs_per_capita","year_pd"]].head(20)
# Out:
#            county                        race_label_value  n_employed  \
# 0         Alameda                             White Alone    360841.0
# 1         Alameda         Black or African American Alone     57709.0
# 2         Alameda  American Indian or Alaska Native Alone      7701.0
# 3         Alameda                             Asian Alone    167632.0
# 6    Contra Costa                             White Alone    197550.0
# 7    Contra Costa         Black or African American Alone     24567.0
# 8    Contra Costa  American Indian or Alaska Native Alone      3682.0
# 9    Contra Costa                             Asian Alone     58412.0
# 12          Marin                             White Alone     63818.0
# 13          Marin         Black or African American Alone      5110.0
# 14          Marin  American Indian or Alaska Native Alone      1079.0
# 15          Marin                             Asian Alone     12066.0
# 18           Napa                             White Alone     45034.0
# 19           Napa         Black or African American Alone      2608.0
# 20           Napa  American Indian or Alaska Native Alone       838.0
# 21           Napa                             Asian Alone      4977.0
# 24  San Francisco                             White Alone    332267.0
# 25  San Francisco         Black or African American Alone     35699.0
# 26  San Francisco  American Indian or Alaska Native Alone      4825.0
# 27  San Francisco                             Asian Alone    164507.0
#
#    population_by_race jobs_per_capita    year_pd
# 0              523391        0.689429 2018-01-01
# 1              172329        0.334877 2018-01-01
# 2                5288        1.456316 2018-01-01
# 3              483067        0.347016 2018-01-01
# 6              502951        0.392782 2018-01-01
# 7               93683        0.262235 2018-01-01
# 8                2376        1.549663 2018-01-01
# 9              182135        0.320707 2018-01-01
# 12             185809         0.34346 2018-01-01
# 13               5597        0.912989 2018-01-01
# 14                435         2.48046 2018-01-01
# 15              14815        0.814445 2018-01-01
# 18              74159        0.607263 2018-01-01
# 19               2764         0.94356 2018-01-01
# 20                326        2.570552 2018-01-01
# 21              11210        0.443979 2018-01-01
# 24             353670        0.939483 2018-01-01
# 25              43619        0.818428 2018-01-01
# 26               1363        3.539985 2018-01-01
# 27             294846        0.557942 2018-01-01

# %%
# looks good we can save it in "processed" we will change year into datetime later

df_race_plot.to_csv(
    PROCESSED_DIR / "df_race_plot.csv",
    index=False
)

# %%
fig = plot_jobs_per_capita_by_race(
    df=df_race_plot,
    county_name="San Francisco"
)

fig.write_html(
    VIS_DIR / "jobs_per_capita_race_san_francisco.html"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e98b673b-7380-4e0e-9020-d610c03b6da2" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e98b673b-7380-4e0e-9020-d610c03b6da2")) {                    Plotly.newPlot(                        "e98b673b-7380-4e0e-9020-d610c03b6da2",                        [{"hovertemplate":"Race:=White Alone\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total employed \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"White Alone","line":{"color":"rgb(102, 197, 204)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"White Alone","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.9394831339949671,0.9647906597483797,0.9163550476540326,0.8760182863884383,0.9902424056459036,1.047783670696743,1.0346150951915118],"yaxis":"y","type":"scatter"},{"hovertemplate":"Race:=Black or African American Alone\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total employed \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Black or African American Alone","line":{"color":"rgb(246, 207, 113)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Black or African American Alone","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.8184277493752723,0.8613357087387511,0.81564376328762,0.7714459922142488,0.8835789574092622,0.9734860721119201,0.9894155427103404],"yaxis":"y","type":"scatter"},{"hovertemplate":"Race:=Asian Alone\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total employed \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asian Alone","line":{"color":"rgb(248, 156, 116)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Asian Alone","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.5579421121534631,0.5802326673554551,0.5475563359672228,0.5304433197352607,0.602699752063586,0.6291517875608378,0.6114539875185325],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatm ...

# %%
fig = plot_jobs_per_capita_by_race(
    df=df_race_plot,
    county_name="Alameda"
)
fig.write_html(
    VIS_DIR / "jobs_per_capita_race_alameda.html"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52b23834-5f8e-423e-9c6c-d8fbb5a26fba" class="plotly-graph-div" style="height:600px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52b23834-5f8e-423e-9c6c-d8fbb5a26fba")) {                    Plotly.newPlot(                        "52b23834-5f8e-423e-9c6c-d8fbb5a26fba",                        [{"hovertemplate":"Race:=White Alone\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total employed \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"White Alone","line":{"color":"rgb(102, 197, 204)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"White Alone","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.6894291265994257,0.6991759007161152,0.6655727776980355,0.6797970904288315,0.725895062488204,0.7831405631960896,0.8145981300555851],"yaxis":"y","type":"scatter"},{"hovertemplate":"Race:=Black or African American Alone\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total employed \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Black or African American Alone","line":{"color":"rgb(246, 207, 113)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Black or African American Alone","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.33487689245570973,0.3428269302673397,0.32637046068517056,0.3242679966509454,0.35235503960336173,0.381848819808604,0.3966237608345876],"yaxis":"y","type":"scatter"},{"hovertemplate":"Race:=Asian Alone\u003cbr\u003eYear=%{x}\u003cbr\u003eJobs per Capita (total employed \u002f total population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asian Alone","line":{"color":"rgb(248, 156, 116)","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Asian Alone","orientation":"v","showlegend":true,"x":["2018-01-01T00:00:00","2019-01-01T00:00:00","2020-01-01T00:00:00","2021-01-01T00:00:00","2022-01-01T00:00:00","2023-01-01T00:00:00","2024-01-01T00:00:00"],"xaxis":"x","y":[0.3470160453932891,0.3464695991580747,0.3149746168256957,0.3169339784372738,0.33236220783843284,0.34286693024109677,0.33991137808925226],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]} ...

# %%
# we want to do a choropleth map by race in 2024 to show differences in jobs per capita by county
map_race_df = df_race_plot[df_race_plot["year_pd"].dt.year == 2024].copy()

# %%
# we create a benchmark for coloring scheme (White as it's maximum seems to be 1)
white_df = map_race_df[map_race_df["race_label_value"] == "White Alone"].copy()

white_vmin = white_df["jobs_per_capita"].min()
white_vmax = white_df["jobs_per_capita"].max()

# %%
import matplotlib.pyplot as plt
# sets font to Serif for consistency for ArcGIS story map - Serif looks closer to Times New Roman and Georgia
plt.rcParams["font.family"] = "serif"
for race in map_race_df["race_label_value"].unique():

    race_df = map_race_df[map_race_df["race_label_value"] == race].copy()

    race_gdf = gdf.merge(
        race_df[["county", "jobs_per_capita"]],
        left_on="CountyName",
        right_on="county",
        how="left"
    )

    race_gdf = race_gdf[race_gdf["jobs_per_capita"].notna()].copy()
    race_gdf["jobs_per_capita"] = pd.to_numeric( # convert to numeric
        race_gdf["jobs_per_capita"],
        errors="coerce"
    ).round(2)
    race_gdf = race_gdf.to_crs("EPSG:3310")

    fig, ax = plt.subplots(figsize=(8, 8))

    race_gdf.plot(
        column="jobs_per_capita",
        cmap="PuRd", #colors chosen from colorbrewer palette for color-blind safe options and divergent color scale to indicate below and above the benchmark
        vmin=white_vmin, # benchmark for coloring
        vmax=white_vmax,
        legend_kwds={"label": "Jobs per capita (total employed / total population)"}, # we decide not to use natural_breaks due to readability
        legend=True,
        edgecolor="black",
        linewidth=0.3,
        ax=ax
    )

    ax.set_title(f"Jobs per Capita by County (2024)\n{race}", fontsize=14)
    ax.axis("off")

    plt.savefig(
        f"visualizations/jobs_per_capita_map_2024_{race.replace(' ', '_')}.png",
        dpi=300,
        bbox_inches="tight"
    )

       # save map into visualizations folder
    plt.savefig(
        VIS_DIR / f"jobs_per_capita_map_2024_{race.replace(' ', '_')}.png",
        dpi=300,
        bbox_inches="tight"
    )
    plt.show()

# %%
###### SECTION 5 ########

# JOBS PER CAPITA BY ETHNICITY BY COUNTY

df_ethnicity = county_df[
    (county_df["industry"] == "00") & # all industries filtered
    (county_df["race"] == "A0") & # this time race is not filtered to all as we are not interested in this variable now
    (county_df["ownercode"] == "A05") &
    (county_df["firmsize"] == 0) &
    (county_df["ethnicity"] != "A0")  #this time ethnicity
].copy()

# %%
df_ethnicity.head()
# Out:
#      geo_level geo_level_label_value  geography geography_label_value  \
# 1            C              Counties       6001           Alameda, CA
# 2            C              Counties       6001           Alameda, CA
# 2437         C              Counties       6013      Contra Costa, CA
# 2438         C              Counties       6013      Contra Costa, CA
# 4873         C              Counties       6041             Marin, CA
#
#      ind_level industry industry_label_value ownercode ownercode_label_value  \
# 1            A       00    All NAICS Sectors       A05           All Private
# 2            A       00    All NAICS Sectors       A05           All Private
# 2437         A       00    All NAICS Sectors       A05           All Private
# 2438         A       00    All NAICS Sectors       A05           All Private
# 4873         A       00    All NAICS Sectors       A05           All Private
#
#      race race_label_value ethnicity   ethnicity_label_value  firmsize  \
# 1      A0        All Races        A1  Not Hispanic or Latino         0
# 2      A0        All Races        A2      Hispanic or Latino         0
# 2437   A0        All Races        A1  Not Hispanic or Latino         0
# 2438   A0        All Races        A2      Hispanic or Latino         0
# 4873   A0        All Races        A1  Not Hispanic or Latino         0
#
#      firmsize_label_value  agg_level     year_pd  n_employed
# 1          All Firm Sizes       4137  2018-01-01    472770.0
# 2          All Firm Sizes       4137  2018-01-01    151416.0
# 2437       All Firm Sizes       4137  2018-01-01    223871.0
# 2438       All Firm Sizes       4137  2018-01-01     74672.0
# 4873       All Firm Sizes       4137  2018-01-01     66228.0

# %%
# check ethnicity names so to check they are all there
df_ethnicity[["ethnicity", "ethnicity_label_value"]].drop_duplicates().sort_values("ethnicity")
# Out:
#   ethnicity   ethnicity_label_value
# 1        A1  Not Hispanic or Latino
# 2        A2      Hispanic or Latino

# %%
# transform year in datetime. we know this is not necessary but we keeep it consistent as it might be useful in the future
df_ethnicity["year_pd"] = pd.to_datetime(df_ethnicity["year_pd"])

# %%
# drop missing employment before grouping
df_ethnicity = df_ethnicity.dropna(subset=["n_employed"])

# %%
# adjust county names from San Francisco, CA to San Francisco to mantain consistency
df_ethnicity["county"] = df_ethnicity["geography_label_value"].str.replace(", CA", "", regex=False)

# %%
# merge df_race with acs_all_df so to calculate jobs per capita
df_ethnicity = df_ethnicity.merge(
    acs_all_df,
    on=["county", "year_pd"],
    how="left"
)

df_ethnicity.head()
# Out:
#   geo_level geo_level_label_value  geography geography_label_value ind_level  \
# 0         C              Counties       6001           Alameda, CA         A
# 1         C              Counties       6001           Alameda, CA         A
# 2         C              Counties       6013      Contra Costa, CA         A
# 3         C              Counties       6013      Contra Costa, CA         A
# 4         C              Counties       6041             Marin, CA         A
#
#   industry industry_label_value ownercode ownercode_label_value race  ...  \
# 0       00    All NAICS Sectors       A05           All Private   A0  ...
# 1       00    All NAICS Sectors       A05           All Private   A0  ...
# 2       00    All NAICS Sectors       A05           All Private   A0  ...
# 3       00    All NAICS Sectors       A05           All Private   A0  ...
# 4       00    All NAICS Sectors       A05           All Private   A0  ...
#
#   agg_level    year_pd n_employed        county pop_total  pop_white  \
# 0      4137 2018-01-01   472770.0       Alameda   1643700     523391
# 1      4137 2018-01-01   151416.0       Alameda   1643700     523391
# 2      4137 2018-01-01   223871.0  Contra Costa   1133247     502951
# 3      4137 2018-01-01    74672.0  Contra Costa   1133247     502951
# 4      4137 2018-01-01    66228.0         Marin    260295     185809
#
#   pop_black  pop_native pop_asian  pop_hispanic
# 0    172329        5288    483067        369061
# 1    172329        5288    483067        369061
# 2     93683        2376    182135        288101
# 3     93683        2376    182135        288101
# 4      5597         435     14815         41335
#
# [5 rows x 25 columns]

# %%
# using the function 6

ethnicity_map = {
    "A2":"pop_hispanic",
    "A1":"pop_total"
}

df_ethnicity = map_ethnicity_population(df_ethnicity, ethnicity_map=ethnicity_map)

# %%
df_ethnicity.head()
# Out:
#   geo_level geo_level_label_value  geography geography_label_value ind_level  \
# 0         C              Counties       6001           Alameda, CA         A
# 1         C              Counties       6001           Alameda, CA         A
# 2         C              Counties       6013      Contra Costa, CA         A
# 3         C              Counties       6013      Contra Costa, CA         A
# 4         C              Counties       6041             Marin, CA         A
#
#   industry industry_label_value ownercode ownercode_label_value race  ...  \
# 0       00    All NAICS Sectors       A05           All Private   A0  ...
# 1       00    All NAICS Sectors       A05           All Private   A0  ...
# 2       00    All NAICS Sectors       A05           All Private   A0  ...
# 3       00    All NAICS Sectors       A05           All Private   A0  ...
# 4       00    All NAICS Sectors       A05           All Private   A0  ...
#
#      year_pd n_employed        county  pop_total pop_white  pop_black  \
# 0 2018-01-01   472770.0       Alameda    1643700    523391     172329
# 1 2018-01-01   151416.0       Alameda    1643700    523391     172329
# 2 2018-01-01   223871.0  Contra Costa    1133247    502951      93683
# 3 2018-01-01    74672.0  Contra Costa    1133247    502951      93683
# 4 2018-01-01    66228.0         Marin     260295    185809       5597
#
#   pop_native  pop_asian pop_hispanic  population_by_ethnicity
# 0       5288     483067       369061                  1643700
# 1       5288     483067       369061                   369061
# 2       2376     182135       288101                  1133247
# 3       2376     182135       288101                   288101
# 4        435      14815        41335                   260295
#
# [5 rows x 26 columns]

# %%
df_ethnicity = df_ethnicity[df_ethnicity["population_by_ethnicity"].notna()]

# %%
df_ethnicity.head()
# Out:
#   geo_level geo_level_label_value  geography geography_label_value ind_level  \
# 0         C              Counties       6001           Alameda, CA         A
# 1         C              Counties       6001           Alameda, CA         A
# 2         C              Counties       6013      Contra Costa, CA         A
# 3         C              Counties       6013      Contra Costa, CA         A
# 4         C              Counties       6041             Marin, CA         A
#
#   industry industry_label_value ownercode ownercode_label_value race  ...  \
# 0       00    All NAICS Sectors       A05           All Private   A0  ...
# 1       00    All NAICS Sectors       A05           All Private   A0  ...
# 2       00    All NAICS Sectors       A05           All Private   A0  ...
# 3       00    All NAICS Sectors       A05           All Private   A0  ...
# 4       00    All NAICS Sectors       A05           All Private   A0  ...
#
#      year_pd n_employed        county  pop_total pop_white  pop_black  \
# 0 2018-01-01   472770.0       Alameda    1643700    523391     172329
# 1 2018-01-01   151416.0       Alameda    1643700    523391     172329
# 2 2018-01-01   223871.0  Contra Costa    1133247    502951      93683
# 3 2018-01-01    74672.0  Contra Costa    1133247    502951      93683
# 4 2018-01-01    66228.0         Marin     260295    185809       5597
#
#   pop_native  pop_asian pop_hispanic  population_by_ethnicity
# 0       5288     483067       369061                  1643700
# 1       5288     483067       369061                   369061
# 2       2376     182135       288101                  1133247
# 3       2376     182135       288101                   288101
# 4        435      14815        41335                   260295
#
# [5 rows x 26 columns]

# %%
# let's build the recovery index also for ethnicity/hispanic population
df_ethnicity = add_baseline(
    df_ethnicity,
    value_col="n_employed",
    baseline_year=2019,
    group_cols=["county", "ethnicity"],
    baseline_col="baseline_emp_ethnicity"
)

# %%
# recovery index calculation for ethnicity using Function 2
df_ethnicity = add_recovery_index(
    df_ethnicity,
    current_col="n_employed",
    baseline_col="baseline_emp_ethnicity",
    recovery_col="recovery_index_ethnicity"
)

# %%
# let's drop any missing population_by_ethnicity before computing jobs per capita
# we create a new df because otherwise we would lose data for future work (original is df_ethnicity)
df_ethnicity_plot = df_ethnicity.dropna(subset=["population_by_ethnicity"])

# %%
df_ethnicity_plot[[
    "county", "ethnicity", "ethnicity_label_value",
    "pop_hispanic", "population_by_ethnicity", "n_employed"
]].head(15)
# Out:
#            county ethnicity   ethnicity_label_value  pop_hispanic  \
# 0         Alameda        A1  Not Hispanic or Latino        369061
# 1         Alameda        A2      Hispanic or Latino        369061
# 2    Contra Costa        A1  Not Hispanic or Latino        288101
# 3    Contra Costa        A2      Hispanic or Latino        288101
# 4           Marin        A1  Not Hispanic or Latino         41335
# 5           Marin        A2      Hispanic or Latino         41335
# 6            Napa        A1  Not Hispanic or Latino         47687
# 7            Napa        A2      Hispanic or Latino         47687
# 8   San Francisco        A1  Not Hispanic or Latino        132651
# 9   San Francisco        A2      Hispanic or Latino        132651
# 10      San Mateo        A1  Not Hispanic or Latino        189002
# 11      San Mateo        A2      Hispanic or Latino        189002
# 12    Santa Clara        A1  Not Hispanic or Latino        495455
# 13    Santa Clara        A2      Hispanic or Latino        495455
# 14         Solano        A1  Not Hispanic or Latino        114406
#
#    population_by_ethnicity  n_employed
# 0                  1643700    472770.0
# 1                   369061    151416.0
# 2                  1133247    223871.0
# 3                   288101     74672.0
# 4                   260295     66228.0
# 5                    41335     19487.0
# 6                   140530     36361.0
# 7                    47687     19297.0
# 8                   870044    465885.0
# 9                   132651     95726.0
# 10                  765935    270462.0
# 11                  189002     68829.0
# 12                 1922200    705893.0
# 13                  495455    189595.0
# 14                  438530     71852.0

# %%
#calculate jobs_per_capita with the races available
df_ethnicity_plot["jobs_per_capita"] = df_ethnicity["n_employed"] / df_ethnicity["population_by_ethnicity"]

# %%
# looks good we can save it in "processed" we will change year into datetime later

df_ethnicity_plot.to_csv(
    PROCESSED_DIR / "df_ethnicity_plot.csv",
    index=False
)

# %%
# we want to do a choropleth map by race in 2024 to show differences in jobs per capita by county
map_ethnicity_df = df_ethnicity_plot[df_ethnicity_plot["year_pd"].dt.year == 2024].copy()

# %%
map_ethnicity_df.head()
# Out:
#     geo_level geo_level_label_value  geography geography_label_value  \
# 108         C              Counties       6001           Alameda, CA
# 109         C              Counties       6001           Alameda, CA
# 110         C              Counties       6013      Contra Costa, CA
# 111         C              Counties       6013      Contra Costa, CA
# 112         C              Counties       6041             Marin, CA
#
#     ind_level industry industry_label_value ownercode ownercode_label_value  \
# 108         A       00    All NAICS Sectors       A05           All Private
# 109         A       00    All NAICS Sectors       A05           All Private
# 110         A       00    All NAICS Sectors       A05           All Private
# 111         A       00    All NAICS Sectors       A05           All Private
# 112         A       00    All NAICS Sectors       A05           All Private
#
#     race  ... pop_total pop_white pop_black  pop_native pop_asian  \
# 108   A0  ...   1649473    452099    154136        3417    539370
# 109   A0  ...   1649473    452099    154136        3417    539370
# 110   A0  ...   1165012    443990     92564        1832    217115
# 111   A0  ...   1165012    443990     92564        1832    217115
# 112   A0  ...    257969    167816      5379         166     15705
#
#      pop_hispanic population_by_ethnicity  baseline_emp_ethnicity  \
# 108        386114                 1649473                476774.0
# 109        386114                  386114                156843.0
# 110        321749                 1165012                224936.0
# 111        321749                  321749                 76971.0
# 112         50216                  257969                 65803.0
#
#     recovery_index_ethnicity  jobs_per_capita
# 108               101.196374         0.292504
# 109               110.346652         0.448238
# 110                98.293292         0.189781
# 111               111.341934          0.26636
# 112                98.597328         0.251503
#
# [5 rows x 29 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
# sets font to Serif for consistency for ArcGIS story map - Serif looks closer to Times New Roman
plt.rcParams["font.family"] = "serif"
# Keeps only rows with valid jobs_per_capita
ethnicity_df = map_ethnicity_df[
    map_ethnicity_df["jobs_per_capita"].notna()
].copy()
ethnicity_df["jobs_per_capita"] = pd.to_numeric(
    ethnicity_df["jobs_per_capita"],
    errors="coerce"
).round(2)

ethnicity_df = ethnicity_df[
    ethnicity_df["jobs_per_capita"].notna()
].copy()

# Merges county geometries with jobs per capita data
ethnicity_gdf = gdf.merge(
    ethnicity_df[["county", "jobs_per_capita"]],
    left_on="CountyName",
    right_on="county",
    how="left"
)
ethnicity_gdf = ethnicity_gdf[
    ethnicity_gdf["jobs_per_capita"].notna()
].copy()
ethnicity_gdf = ethnicity_gdf.to_crs("EPSG:3310")
fig, ax = plt.subplots(figsize=(8, 8))
ethnicity_gdf.plot(
    column="jobs_per_capita",
    cmap="PuRd",      #colors for color-blind safe and divergent scheme, selected from colorbrewer
    vmin=white_vmin,     #benchmark that is same as the race ones to maintain consistency
    vmax=white_vmax,
    legend=True,
    legend_kwds={
        "label": "Jobs per capita",
        "shrink": 0.7
    },
    edgecolor="black",
    linewidth=0.3,
    ax=ax
)
ax.set_title(
    "Jobs per Capita by County - Hispanic Population (2024)",
    fontsize=14
)
ax.axis("off")
plt.savefig(
    "visualizations/jobs_per_capita_map_2024_ethnicity.png",
    dpi=300,
    bbox_inches="tight"
)

# save map into visualizations folder
plt.savefig(
    VIS_DIR / "jobs_per_capita_map_2024_ethnicity.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %%
# printing the requirements

with open("requirements.txt", "w") as f:

    f.write("""pandas
numpy
matplotlib
plotly
geopandas
shapely
fiona
pyproj
pyogrio
jupyter
notebook
""")

# %%
from google.colab import files
files.download("requirements.txt")
